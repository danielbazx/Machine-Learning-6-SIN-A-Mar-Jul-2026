# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.11.1 x86_64-unknown-linux-gnu
# installing to /home/codespace/.local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !uv self update
# Out:
# info: Checking for updates...
# success: You're already on version v0.11.1 of uv (the latest version).

# %% [markdown]
# #Creating virtual environment
#     1  uv venv mienv
#     2  source mienv/bin/activate
#     3  uv pip install ipykernel
#     4  python -m ipykernel install --user --name=mienv

# %%
# !uv pip install numpy
# !uv pip install pandas
# Out:
# Using Python 3.12.1 environment at: mienv
# Checked 1 package in 2ms
# Using Python 3.12.1 environment at: mienv
# Checked 1 package in 8ms

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1,3,5,np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
date = pd.date_range("20260102", periods=6)
date
# Out:
# DatetimeIndex(['2026-01-02', '2026-01-03', '2026-01-04', '2026-01-05',
#                '2026-01-06', '2026-01-07'],
#               dtype='datetime64[us]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=date, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2026-01-02 -0.297329 -0.993678  1.864455 -0.817321
# 2026-01-03  1.486170  0.116380 -2.090107 -0.113905
# 2026-01-04  1.523590 -1.090341 -0.034285 -1.245182
# 2026-01-05  0.707185 -1.076891 -0.288759  0.390494
# 2026-01-06 -1.122536  0.221478 -0.237060  1.154147
# 2026-01-07  0.678970  1.019095  0.036183 -0.348149

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20260326"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3]*4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2026-03-26  1.0  3   test  foo
# 1  1.0 2026-03-26  1.0  3  train  foo
# 2  1.0 2026-03-26  1.0  3   test  foo
# 3  1.0 2026-03-26  1.0  3  train  foo
