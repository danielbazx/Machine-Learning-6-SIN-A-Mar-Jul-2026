# %%
#import panda, numpy, matplotlib libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Dataset importation 
unemployment = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/data/country_total.csv')

# %%
#Type of "unemployment", it is a dataframe
type(unemployment)
# Out:
# pandas.DataFrame

# %%
#To see the first 5 rows of the data frame
unemployment.head()
# Out:
#   country seasonality    month  unemployment  unemployment_rate
# 0      at         nsa  1993.01        171000                4.5
# 1      at         nsa  1993.02        175000                4.6
# 2      at         nsa  1993.03        166000                4.4
# 3      at         nsa  1993.04        157000                4.1
# 4      at         nsa  1993.05        147000                3.9

# %%
#To see the quantity of columns and rows in the dataset
unemployment.shape
# Out:
# (20796, 5)

# %%
#To see all the columns (including its names) of the dataframe
unemployment.columns
# Out:
# Index(['country', 'seasonality', 'month', 'unemployment', 'unemployment_rate'], dtype='str')

# %%
#To see the type of data of each columns
unemployment.dtypes
# Out:
# country                  str
# seasonality              str
# month                float64
# unemployment           int64
# unemployment_rate    float64
# dtype: object

# %%
#To see a summarized statistics view of the dataframe
unemployment.describe
# Out:
# <bound method NDFrame.describe of       country seasonality    month  unemployment  unemployment_rate
# 0          at         nsa  1993.01        171000                4.5
# 1          at         nsa  1993.02        175000                4.6
# 2          at         nsa  1993.03        166000                4.4
# 3          at         nsa  1993.04        157000                4.1
# 4          at         nsa  1993.05        147000                3.9
# ...       ...         ...      ...           ...                ...
# 20791      uk       trend  2010.06       2429000                7.7
# 20792      uk       trend  2010.07       2422000                7.7
# 20793      uk       trend  2010.08       2429000                7.7
# 20794      uk       trend  2010.09       2447000                7.8
# 20795      uk       trend  2010.10       2455000                7.8
#
# [20796 rows x 5 columns]>

# %%
#Creation of an array
my_list = ['a', 'b', 'c', 'd', 'e', 'f']

# %%
#Print of the last 4 elements of the array
my_list[len(my_list)-4:]
# Out:
# ['c', 'd', 'e', 'f']

# %%
#Importation of countries.csv dataset
countries = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/data/countries.csv')

# %%
countries.shape
# Out:
# (30, 8)

# %%
countries.columns
# Out:
# Index(['country', 'google_country_code', 'country_group', 'name_en', 'name_fr',
#        'name_de', 'latitude', 'longitude'],
#       dtype='str')

# %%
countries.head()
# Out:
#   country google_country_code country_group   name_en   name_fr     name_de  \
# 0      at                  AT            eu   Austria  Autriche  Österreich
# 1      be                  BE            eu   Belgium  Belgique     Belgien
# 2      bg                  BG            eu  Bulgaria  Bulgarie   Bulgarien
# 3      hr                  HR        non-eu   Croatia   Croatie    Kroatien
# 4      cy                  CY            eu    Cyprus    Chypre      Zypern
#
#     latitude  longitude
# 0  47.696554  13.345980
# 1  50.501045   4.476674
# 2  42.725674  25.482322
# 3  44.746643  15.340844
# 4  35.129141  33.428682

# %%
countries.tail()
# Out:
#    country google_country_code country_group         name_en      name_fr  \
# 25      si                  SI            eu        Slovenia     Slovénie
# 26      es                  ES            eu           Spain      Espagne
# 27      se                  SE            eu          Sweden        Suède
# 28      tr                  TR        non-eu          Turkey      Turquie
# 29      uk                  GB            eu  United Kingdom  Royaume-Uni
#
#                    name_de   latitude  longitude
# 25               Slowenien  46.149259  14.986617
# 26                 Spanien  39.895013  -2.988296
# 27                Schweden  62.198467  14.896307
# 28                  Türkei  38.952942  35.439795
# 29  Vereinigtes Königreich  54.315447  -2.232612

# %%
countries.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              30 non-null     str
#  1   google_country_code  30 non-null     str
#  2   country_group        30 non-null     str
#  3   name_en              30 non-null     str
#  4   name_fr              30 non-null     str
#  5   name_de              30 non-null     str
#  6   latitude             30 non-null     float64
#  7   longitude            30 non-null     float64
# dtypes: float64(2), str(6)
# memory usage: 2.0 KB

# %%
countries.describe()
# Out:
#         latitude  longitude
# count  30.000000  30.000000
# mean   49.092609  14.324579
# std     7.956624  11.257010
# min    35.129141  -8.239122
# 25%    43.230916   6.979186
# 50%    49.238087  14.941462
# 75%    54.090400  23.351690
# max    64.950159  35.439795
